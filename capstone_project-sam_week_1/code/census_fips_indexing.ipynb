# %%
import pandas as pd

# %%
df = pd.read_csv('../data_sources/co-est2021-alldata.csv', encoding = 'latin-1')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RESIDUAL2021  \
# 0            5024279          5024803          5039877  ...           242
# 1              58805            58877            59095  ...             8
# 2             231767           233140           239294  ...           -82
# 3              25223            25180            24964  ...             1
# 4              22293            22223            22477  ...            -1
#
#    GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# ...

# %%
state_rows = df.loc[df['COUNTY']==0]

# %%
state_rows
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY                STNAME  \
# 0         40       3         6      1       0               Alabama
# 68        40       4         9      2       0                Alaska
# 99        40       4         8      4       0               Arizona
# 115       40       3         7      5       0              Arkansas
# 191       40       4         9      6       0            California
# 250       40       4         8      8       0              Colorado
# 315       40       1         1      9       0           Connecticut
# 324       40       3         5     10       0              Delaware
# 328       40       3         5     11       0  District of Columbia
# 330       40       3         5     12       0               Florida
# 398       40       3         5     13       0               Georgia
# 558       40       4         9     15       0                Hawaii
# 564       40       4         8     16       0                 Idaho
# ...

# %%
counties_df = df.drop(index = state_rows.index)

# %%
counties_df['COUNTY'] = counties_df['COUNTY'].astype('str')

# %%
counties_df['COUNTY'] = counties_df['COUNTY'].str.zfill(3)
counties_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1    001  Alabama  Autauga County
# 2      50       3         6      1    003  Alabama  Baldwin County
# 3      50       3         6      1    005  Alabama  Barbour County
# 4      50       3         6      1    007  Alabama     Bibb County
# 5      50       3         6      1    009  Alabama   Blount County
#
#    ESTIMATESBASE2020  POPESTIMATE2020  POPESTIMATE2021  ...  RESIDUAL2021  \
# 1              58805            58877            59095  ...             8
# 2             231767           233140           239294  ...           -82
# 3              25223            25180            24964  ...             1
# 4              22293            22223            22477  ...            -1
# 5              59134            59081            59041  ...             9
#
#    GQESTIMATESBASE2020  GQESTIMATES2020  GQESTIMATES2021  RBIRTH2021  \
# ...

# %%
counties_df['STATE'] = counties_df['STATE'].astype('str')

# %%
counties_df['FIPS'] = counties_df['STATE']+counties_df['COUNTY']

# %%
counties_df = counties_df.set_index(counties_df['FIPS'])

# %%
counties_df.loc['22113']
# Out:
# SUMLEV                                 50
# REGION                                  3
# DIVISION                                7
# STATE                                  22
# COUNTY                                113
# STNAME                          Louisiana
# CTYNAME                  Vermilion Parish
# ESTIMATESBASE2020                   57359
# POPESTIMATE2020                     57289
# POPESTIMATE2021                     57204
# NPOPCHG2020                           -70
# NPOPCHG2021                           -85
# BIRTHS2020                            168
# BIRTHS2021                            686
# DEATHS2020                            167
# DEATHS2021                            709
# NATURALCHG2020                          1
# NATURALCHG2021                        -23
# INTERNATIONALMIG2020                    0
# INTERNATIONALMIG2021                   11
# DOMESTICMIG2020                       -71
# DOMESTICMIG2021                       -81
# ...

# %%
counties_df = counties_df.drop(columns = ['SUMLEV','REGION','DIVISION','STATE','COUNTY','FIPS','STNAME','CTYNAME'])

# %%
counties_df.count()[1]
# Out:
# 3143

# %%
counties_df.to_csv('../modified_data/co-est2021-alldata_FIPS.csv')
