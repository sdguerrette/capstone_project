# 3077     76.730879  68.422269   69.413532
#
# [3078 rows x 103 columns]

# %%
#set index to FIPS
df = df.set_index(df['FIPS'])
df= df.drop('FIPS', axis=1)

# %%
#rename target column
df = df.rename(columns={'3/31/21':'first_year_cases'})

# %%
#create variable for case% for each counties population
df['case_pct'] = df['first_year_cases']/df['E_TOTPOP']*100
df['case_pct'].head()
# Out:
# FIPS
# 1001.0    11.936594
# 1003.0     9.853104
# 1005.0     8.637809
# 1007.0    11.284237
# 1009.0    11.178767
# Name: case_pct, dtype: float64

# %%
df['case_pct'].describe()
# Out:
# count    3078.000000
# mean        9.412435
# std         3.068056
# min         0.000000
# 25%         7.699891
# 50%         9.453957
# 75%        11.173830
# max        38.010657
# Name: case_pct, dtype: float64

# %%
# bin and cut the case_pct column into 2 classifications
# q = df['case_pct'].quantile(.75)
q = df['case_pct'].quantile(.85)
bins = [0, q , 40]
labels = ['low','high']
df['case_class'] = pd.cut(df['case_pct'], bins, labels = labels)
df['case_class']
# Out:
# FIPS
# 1001.0      low
# 1003.0      low
# 1005.0      low
# 1007.0      low
# 1009.0      low
#            ...
# 56037.0     low
# 56039.0    high
# 56041.0     low
# 56043.0     low
# 56045.0     low
# Name: case_class, Length: 3078, dtype: category
# Categories (2, object): ['low' < 'high']

# %%
df['case_class'].value_counts()
# Out:
# low     2590
# high     462
# Name: case_class, dtype: int64

# %%
#drop unneeded columns
df = df.drop('case_pct', axis =1)
df
# Out:
#          first_year_cases     AREA_SQMI  E_TOTPOP      E_HU     E_HH    E_POV  \
# FIPS
# 1001.0               6589    594.443459   55200.0   23315.0  21115.0   8422.0
# 1003.0              20505   1589.793007  208107.0  111945.0  78622.0  21653.0
# 1005.0               2227    885.001636   25782.0   11937.0   9186.0   6597.0
# 1007.0               2542    622.461089   22527.0    9161.0   6840.0   2863.0
# 1009.0               6444    644.830460   57645.0   24222.0  20600.0   8220.0
# ...                   ...           ...       ...       ...      ...      ...
# 56037.0              4022  10426.975725   44117.0   19628.0  15871.0   5237.0
# 56039.0              3609   3996.844622   23059.0   13680.0   9158.0   1619.0
# 56041.0              2128   2081.719807   20609.0    8972.0   7735.0   2552.0
# 56043.0               891   2238.672972    8129.0    3868.0   3422.0    984.0
# 56045.0               633   2398.003891    7100.0    3565.0   3062.0   1171.0
#
#          E_UNEMP    E_PCI  E_NOHSDP  E_AGE65  ...  Hopefulness  \
# FIPS                                          ...
# 1001.0    1065.0  29372.0    4204.0   8050.0  ...    91.163142
# 1003.0    4343.0  31203.0   14310.0  40665.0  ...    82.484017
# 1005.0     918.0  18461.0    4901.0   4634.0  ...    61.927181
# 1007.0     658.0  20199.0    2650.0   3661.0  ...    85.258871
# 1009.0     909.0  22656.0    7861.0  10233.0  ...    79.492703
# ...          ...      ...       ...      ...  ...          ...
# 56037.0   1213.0  32624.0    2549.0   4721.0  ...    82.403142
# 56039.0    210.0  53703.0     958.0   3135.0  ...    84.036899
# 56041.0    614.0  27009.0     934.0   2498.0  ...    84.089095
# 56043.0    253.0  27556.0     590.0   1686.0  ...    87.485019
# 56045.0    117.0  29152.0     389.0   1340.0  ...    80.975991
#
#          Income Per Capita  Neuroticism   Openness  Religiosity  Risk Taking  \
# FIPS
# 1001.0             26168.0    77.925476  78.222354    91.106719    53.333333
# 1003.0             28069.0    77.232120  80.086368    71.771566    67.272980
# 1005.0             17249.0    80.375206  78.783778    73.657368    76.066481
# 1007.0             18988.0    80.813736  77.837027    69.974652    75.136154
# 1009.0             21033.0    78.764620  78.193105    92.045455    57.603815
# ...                    ...          ...        ...          ...          ...
# 56037.0            30945.0    79.384759  79.347081    68.147062    73.938691
# 56039.0            46499.0    71.547359  80.522872    65.399695    79.598153
# 56041.0            25636.0    78.771570  77.859042    67.603416    69.705859
# 56043.0            26325.0    76.249370  77.658224    67.412774    82.820701
# 56045.0            29493.0    79.961075  76.977099    71.535519    75.406846
#
#          Selflessness  Tolerance  Work Ethic  case_class
# FIPS
# 1001.0      82.142857  70.000000   60.380952         low
# 1003.0      75.586018  66.983549   70.972246         low
# 1005.0      78.753019  65.170377   68.704105         low
# 1007.0      76.929754  69.859503   67.931677         low
# 1009.0      79.307632  64.953288   76.000000         low
# ...               ...        ...         ...         ...
# 56037.0     76.390464  67.420658   70.956334         low
# 56039.0     79.698193  70.877600   70.938645        high
# 56041.0     73.332067  67.404487   69.299391         low
# 56043.0     78.925326  74.628788   70.050103         low
# 56045.0     76.730879  68.422269   69.413532         low
#
# [3078 rows x 103 columns]

# %%
#turn case % classifications into binary 
df = pd.get_dummies(df, columns = ['case_class'])
df
# Out:
#          first_year_cases     AREA_SQMI  E_TOTPOP      E_HU     E_HH    E_POV  \
# FIPS
# 1001.0               6589    594.443459   55200.0   23315.0  21115.0   8422.0
# 1003.0              20505   1589.793007  208107.0  111945.0  78622.0  21653.0
# 1005.0               2227    885.001636   25782.0   11937.0   9186.0   6597.0
# 1007.0               2542    622.461089   22527.0    9161.0   6840.0   2863.0
# 1009.0               6444    644.830460   57645.0   24222.0  20600.0   8220.0
# ...                   ...           ...       ...       ...      ...      ...
# 56037.0              4022  10426.975725   44117.0   19628.0  15871.0   5237.0
# 56039.0              3609   3996.844622   23059.0   13680.0   9158.0   1619.0
# 56041.0              2128   2081.719807   20609.0    8972.0   7735.0   2552.0
# 56043.0               891   2238.672972    8129.0    3868.0   3422.0    984.0
# 56045.0               633   2398.003891    7100.0    3565.0   3062.0   1171.0
#
#          E_UNEMP    E_PCI  E_NOHSDP  E_AGE65  ...  Income Per Capita  \
# FIPS                                          ...
# 1001.0    1065.0  29372.0    4204.0   8050.0  ...            26168.0
# 1003.0    4343.0  31203.0   14310.0  40665.0  ...            28069.0
# 1005.0     918.0  18461.0    4901.0   4634.0  ...            17249.0
# 1007.0     658.0  20199.0    2650.0   3661.0  ...            18988.0
# 1009.0     909.0  22656.0    7861.0  10233.0  ...            21033.0
# ...          ...      ...       ...      ...  ...                ...
# 56037.0   1213.0  32624.0    2549.0   4721.0  ...            30945.0
# 56039.0    210.0  53703.0     958.0   3135.0  ...            46499.0
# 56041.0    614.0  27009.0     934.0   2498.0  ...            25636.0
# 56043.0    253.0  27556.0     590.0   1686.0  ...            26325.0
# 56045.0    117.0  29152.0     389.0   1340.0  ...            29493.0
#
#          Neuroticism   Openness  Religiosity  Risk Taking  Selflessness  \
# FIPS
# 1001.0     77.925476  78.222354    91.106719    53.333333     82.142857
# 1003.0     77.232120  80.086368    71.771566    67.272980     75.586018
# 1005.0     80.375206  78.783778    73.657368    76.066481     78.753019
# 1007.0     80.813736  77.837027    69.974652    75.136154     76.929754
# 1009.0     78.764620  78.193105    92.045455    57.603815     79.307632
# ...              ...        ...          ...          ...           ...
# 56037.0    79.384759  79.347081    68.147062    73.938691     76.390464
# 56039.0    71.547359  80.522872    65.399695    79.598153     79.698193
# 56041.0    78.771570  77.859042    67.603416    69.705859     73.332067
# 56043.0    76.249370  77.658224    67.412774    82.820701     78.925326
# 56045.0    79.961075  76.977099    71.535519    75.406846     76.730879
#
#          Tolerance  Work Ethic  case_class_low  case_class_high
# FIPS
# 1001.0   70.000000   60.380952               1                0
# 1003.0   66.983549   70.972246               1                0
# 1005.0   65.170377   68.704105               1                0
# 1007.0   69.859503   67.931677               1                0
# 1009.0   64.953288   76.000000               1                0
# ...            ...         ...             ...              ...
# 56037.0  67.420658   70.956334               1                0
# 56039.0  70.877600   70.938645               0                1
# 56041.0  67.404487   69.299391               1                0
# 56043.0  74.628788   70.050103               1                0
# 56045.0  68.422269   69.413532               1                0
#
# [3078 rows x 104 columns]

# %%
#seperate targets and features
X = df.drop(['case_class_low','case_class_high'], axis=1).values
y=df['case_class_high'].values

# %%
#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net
number_input_features = len(X_train[0])
# hidden_nodes_layer1 = 100
# hidden_nodes_layer2 = 50
hidden_nodes_layer1 = 150
hidden_nodes_layer2 = 100
# hidden_nodes_layer3 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))
# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 150)               15450
#
#  dense_1 (Dense)             (None, 100)               15100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# 2022-08-05 17:16:10.747342: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 73/73 [==============================] - 1s 3ms/step - loss: 436.9327 - accuracy: 0.7578
# Epoch 2/100
# 73/73 [==============================] - 0s 2ms/step - loss: 409.2314 - accuracy: 0.7829
# Epoch 3/100
# 73/73 [==============================] - 0s 2ms/step - loss: 336.8426 - accuracy: 0.7816
# Epoch 4/100
# 73/73 [==============================] - 0s 2ms/step - loss: 345.1465 - accuracy: 0.7799
# Epoch 5/100
# 73/73 [==============================] - 0s 2ms/step - loss: 470.8499 - accuracy: 0.7968
# Epoch 6/100
# 73/73 [==============================] - 0s 2ms/step - loss: 106.1407 - accuracy: 0.7903
# Epoch 7/100
100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9746 - accuracy: 0.9406
# Epoch 98/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.4744 - accuracy: 0.9549
# Epoch 99/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.9628 - accuracy: 0.9259
# Epoch 100/100
# 73/73 [==============================] - 0s 2ms/step - loss: 0.2649 - accuracy: 0.9545

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 25/25 - 0s - loss: 11.2075 - accuracy: 0.9338 - 186ms/epoch - 7ms/step
# Loss: 11.207476615905762, Accuracy: 0.93376624584198

# %%
df.columns.to_list()
# Out:
# ['first_year_cases',
#  'AREA_SQMI',
#  'E_TOTPOP',
#  'E_HU',
#  'E_HH',
#  'E_POV',
#  'E_UNEMP',
#  'E_PCI',
#  'E_NOHSDP',
#  'E_AGE65',
#  'E_AGE17',
#  'E_DISABL',
#  'E_SNGPNT',
#  'E_MINRTY',
#  'E_LIMENG',
#  'E_MUNIT',
#  'E_MOBILE',
#  'E_CROWD',
#  'E_NOVEH',
#  'E_GROUPQ',
#  'EP_POV',
#  'EP_UNEMP',
#  'EP_PCI',
#  'EP_NOHSDP',
#  'EP_AGE65',
#  'EP_AGE17',
#  'EP_DISABL',
#  'EP_SNGPNT',
#  'EP_MINRTY',
#  'EP_LIMENG',
#  'EP_MUNIT',
#  'EP_MOBILE',
#  'EP_CROWD',
#  'EP_NOVEH',
#  'EP_GROUPQ',
#  'EPL_POV',
#  'EPL_UNEMP',
#  'EPL_PCI',
#  'EPL_NOHSDP',
#  'SPL_THEME1',
#  'RPL_THEME1',
#  'EPL_AGE65',
#  'EPL_AGE17',
#  'EPL_DISABL',
#  'EPL_SNGPNT',
#  'SPL_THEME2',
#  'RPL_THEME2',
#  'EPL_MINRTY',
#  'EPL_LIMENG',
#  'SPL_THEME3',
#  'RPL_THEME3',
#  'EPL_MUNIT',
#  'EPL_MOBILE',
#  'EPL_CROWD',
#  'EPL_NOVEH',
#  'EPL_GROUPQ',
#  'SPL_THEME4',
#  'RPL_THEME4',
#  'SPL_THEMES',
#  'RPL_THEMES',
#  'F_POV',
#  'F_UNEMP',
#  'F_PCI',
#  'F_NOHSDP',
#  'F_THEME1',
#  'F_AGE65',
#  'F_AGE17',
#  'F_DISABL',
#  'F_SNGPNT',
#  'F_THEME2',
#  'F_MINRTY',
#  'F_LIMENG',
#  'F_THEME3',
#  'F_MUNIT',
#  'F_MOBILE',
#  'F_CROWD',
#  'F_NOVEH',
#  'F_GROUPQ',
#  'F_THEME4',
#  'F_TOTAL',
#  'E_UNINSUR',
#  'EP_UNINSUR',
#  'E_DAYPOP',
#  'Agreeableness',
#  'Belief In Science',
#  'Collectivism',
#  'Conflict Awareness',
#  'Conscientiousness',
#  'Empathy',
#  'Employment Rate',
#  'Entrepreneurship',
#  'Extraversion',
#  'Gender Equality',
#  'Hopefulness',
#  'Income Per Capita',
#  'Neuroticism',
#  'Openness',
#  'Religiosity',
#  'Risk Taking',
#  'Selflessness',
#  'Tolerance',
#  'Work Ethic',
#  'case_class_low',
#  'case_class_high']
