# %%
import pandas as pd

# %%
df = pd.read_csv('../data_sources/Social Context.csv')
df.head()
# Out:
#    IBRC_Geo_ID  Statefips  Countyfips      Description  Year  \
# 0        10001         10           1  Kent County, DE  2019
# 1        10001         10           1  Kent County, DE  2019
# 2        10001         10           1  Kent County, DE  2019
# 3        10001         10           1  Kent County, DE  2019
# 4        10001         10           1  Kent County, DE  2019
#
#    Social_Context_Code Social_Context_Code_Description  \
# 0                  211                     Hopefulness
# 1                  104                 Employment Rate
# 2                  103               Income Per Capita
# 3                  102                 Income Mobility
# 4                  101                Entrepreneurship
#
#    Social_Context_Domain_Data Time_Period
# 0                   87.332678   1972-2017
# 1                   95.300000        2017
# 2                26118.000000        2017
# 3                   -0.441463        2017
# 4                   10.732984        2013

# %%
df = df.drop(columns = ['Social_Context_Code', 'Time_Period', 'Year'])

# %%
df.head()
# Out:
#    IBRC_Geo_ID  Statefips  Countyfips      Description  \
# 0        10001         10           1  Kent County, DE
# 1        10001         10           1  Kent County, DE
# 2        10001         10           1  Kent County, DE
# 3        10001         10           1  Kent County, DE
# 4        10001         10           1  Kent County, DE
#
#   Social_Context_Code_Description  Social_Context_Domain_Data
# 0                     Hopefulness                   87.332678
# 1                 Employment Rate                   95.300000
# 2               Income Per Capita                26118.000000
# 3                 Income Mobility                   -0.441463
# 4                Entrepreneurship                   10.732984

# %%
sc_df = pd.pivot(df, index = 'IBRC_Geo_ID', columns = 'Social_Context_Code_Description', values = 'Social_Context_Domain_Data')

# %%
sc_df.head()
# Out:
# Social_Context_Code_Description  Agreeableness  Belief In Science  \
# IBRC_Geo_ID
# 1001                                 86.279655          70.833333
# 1003                                 85.603337          63.268161
# 1005                                 87.711609          63.046939
# 1007                                 84.830261          63.262028
# 1009                                 85.548096          33.333333
#
# Social_Context_Code_Description  Collectivism  Conflict Awareness  \
# IBRC_Geo_ID
# 1001                                57.142857           63.444323
# 1003                                67.948815           63.751017
# 1005                                70.099756           51.165707
# 1007                                72.034797           61.796095
# 1009                                80.000000           63.136502
#
# Social_Context_Code_Description  Conscientiousness    Empathy  \
# IBRC_Geo_ID
# 1001                                     84.113820  83.308726
# ...

# %%
sc_df
# Out:
# Social_Context_Code_Description  Agreeableness  Belief In Science  \
# IBRC_Geo_ID
# 1001                                 86.279655          70.833333
# 1003                                 85.603337          63.268161
# 1005                                 87.711609          63.046939
# 1007                                 84.830261          63.262028
# 1009                                 85.548096          33.333333
# ...                                        ...                ...
# 56037                                83.811791          68.303853
# 56039                                82.886955          73.489916
# 56041                                84.272810          67.029022
# 56043                                80.773973          68.663949
# 56045                                88.251855          67.710969
#
# Social_Context_Code_Description  Collectivism  Conflict Awareness  \
# IBRC_Geo_ID
# 1001                                57.142857           63.444323
# ...

# %%
#sc_df.to_csv('./modified_data/social_context_FIPS.csv')
